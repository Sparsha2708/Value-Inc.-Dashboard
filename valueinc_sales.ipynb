# %% [markdown]
# <a href="https://colab.research.google.com/github/Sparsha2708/Value-Inc.-Dashboard/blob/main/valueinc_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#file name=pd.read_csv('file.csv')--format of read csv
data=pd.read_csv('/content/drive/MyDrive/python and tableau course/proj 1/transaction2.csv')
#comma separated values
#this file has no , it has ; so should change initially has almost million rows and 1 freaking column

# %%
data=pd.read_csv('/content/drive/MyDrive/python and tableau course/proj 1/transaction2.csv',sep=";")
#now has 13 columns
#dataframe is table

# %%
#summarise data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# dtypes: float64(2), int64(6), object(5)
# ...

# %%
#access colum-- variable=dataframe['column_name']
cp=data['CostPerItem']
n=data['NumberOfItemsPurchased']
sp=data['SellingPricePerItem']
profit=sp-cp

# %%
profit_transaction=n*profit
cp_transaction=n*cp
sp_transaction=n*sp

# %%
cp_transaction=cp*n
print(type(cp_transaction))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#adding new column to data frame
data['CostPerTransaction']=cp_transaction

# %%
data['SalesPerTransaction']=sp_transaction
print(type(data['SalesPerTransaction']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
markup=(sp_transaction-cp_transaction)/cp_transaction
profit_transaction=sp_transaction-cp_transaction

# %%
data['ProfitPerTransaction']=profit_transaction
data['Markup']=markup

# %%
#rounding markup
data['Markup']=round(markup,2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# ...

# %%
#combining datafields
my_data=str(data['Day'])+'-'+str(data['Month'])+'-'+str(data['Year'])
print(data['Day'].dtype)
# Out:
# int64

# %%
day=data['Day'].astype(str)
#Day=str(data['Day'])
#print(type(Day))
year=data['Year'].astype(str)
print(day.dtype)
# Out:
# object

# %%
my_date=day+'-'+data['Month']+'-'+year
data['date']=my_date
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# ...

# %%
data.iloc[0]
#iloc splits data into subset of data that we can view
#views row with index=0
data.iloc[0:3]
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
#
#                                       ClientKeywords  CostPerTransaction  \
# 0  ['Senior', 'Solo Entrepreneur', '2-5 Year Clie...               70.38
# 1   ['Middle Age', 'Corporation', '2-5 Year Client']               10.56
# ...

# %%
data.iloc[-5:]
# Out:
#          UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 1047583  343560        6386952  2019   Feb   16  08:16:00    450030
# 1047584  276528        6316717  2019   Jan   15  08:56:00   1732143
# 1047585  341082        6140585  2018   Sep    8  10:41:00    487326
# 1047586  336147        6075190  2018   Jul   20  09:32:00    460509
# 1047587      -1        6180020  2018   Oct   10  12:00:00    473739
#
#                             ItemDescription  NumberOfItemsPurchased  \
# 1047583  SET/3 RED GINGHAM ROSE STORAGE BOX                       3
# 1047584  WOOD 2 DRAWER CABINET WHITE FINISH                       6
# 1047585              LUNCH BAG APPLE DESIGN                      15
# 1047586      JUMBO BAG PINK VINTAGE PAISLEY                       3
# 1047587                 SEASIDE FLYING DISC                       6
#
#          CostPerItem  SellingPricePerItem         Country  \
# 1047583         5.18                 8.29  United Kingdom
# ...

# %%
data.head(5)#gives 1st 5 rows
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %%
data.iloc[:,2]#represents all rows n column 2
# Out:
# 0          2019
# 1          2018
# 2          2019
# 3          2018
# 4          2018
#            ...
# 1047583    2019
# 1047584    2019
# 1047585    2018
# 1047586    2018
# 1047587    2018
# Name: Year, Length: 1047588, dtype: int64

# %%
#using split to split the client keyword fields
#new_var=column.str.split("sep",expand=True) expand=true means it splits all items
split_col=data['ClientKeywords'].str.split(',',expand=True)

# %%
#creating new columns for the split columns in client keywords
data['CleintAge']=split_col[0]
data['ClientType']=split_col[1]
data['Lengthofcontract']=split_col[2]

# %%
#using replace to replace[] in client details
data['CleintAge']=data['CleintAge'].str.replace('[','')
data['Lengthofcontract']=data['Lengthofcontract'].str.replace(']','')

# %%
#convert to lower case
data['ItemDescription']=data['ItemDescription'].str.lower()

# %%
seasons=pd.read_csv('/content/drive/MyDrive/python and tableau course/proj 1/value_inc_seasons.csv',sep=';')
#merging files:
#merge_df=pd.merge(df_old,df_new,on='key')

# %%
data=pd.merge(data,seasons,on='Month')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# ...

# %%
seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   12 non-null     object
#  1   Season  12 non-null     object
# dtypes: object(2)
# memory usage: 324.0+ bytes

# %%
#to drop columns(delete)
#df.drop(columns=["age", "address"], inplace=True,axis=1?)
#to rename columns
#df.rename(columns={"old_name": "new_name"}, inplace=True)

# %%
data = data.drop(['ClientKeywords','Year','Day','Month'],axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Time                    1047588 non-null  object
#  3   ItemCode                1047588 non-null  int64
#  4   ItemDescription         1044797 non-null  object
#  5   NumberOfItemsPurchased  1047588 non-null  int64
#  6   CostPerItem             1047588 non-null  float64
#  7   SellingPricePerItem     1047588 non-null  float64
#  8   Country                 1047588 non-null  object
#  9   CostPerTransaction      1047588 non-null  float64
#  10  SalesPerTransaction     1047588 non-null  float64
#  11  ProfitPerTransaction    1047588 non-null  float64
#  12  Markup                  1042743 non-null  float64
# ...

# %%
#export to csv
data.to_csv('ValueIncCleaned2.csv',index=False)
#index=True means index column will also be stored false means it wont
